# %%
import pandas as pd

# %%
dffile = pd.read_csv("telco_churn.csv")

# %%
# Read

# %% [markdown]
# # replacing empty cells in a colum

# %%
dffile
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
dffile['Ratio'] = dffile['Total intl charge']/dffile['Customer service calls']

# %%
dffile.fillna({'çhurn': 'FALSE'}, inplace=True)

# %%
# Reading files

# %%
dffile.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
# filtering base on some specific condition or value

# %%
dffile[(dffile['International plan'] =='Yes') & (dffile['Churn']==True)]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 41      MD             135        408                Yes             Yes
# 115     ME              36        510                Yes             Yes
# 144     VT             117        408                Yes              No
# 198     ME             131        510                Yes             Yes
# 214     FL              70        510                Yes              No
# ...    ...             ...        ...                ...             ...
# 3246    NC              77        408                Yes             Yes
# 3255    RI             138        510                Yes              No
# 3291    MI             119        510                Yes             Yes
# 3304    IL              71        510                Yes              No
# 3320    GA             122        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
dffile
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# # Exporting dataset after clearning

# %%
dffile.head(22)
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 0     KS             128        415                 No             Yes
# 1     OH             107        415                 No             Yes
# 2     NJ             137        415                 No              No
# 3     OH              84        408                Yes              No
# 4     OK              75        415                Yes              No
# 5     AL             118        510                Yes              No
# 6     MA             121        510                 No             Yes
# 7     MO             147        415                Yes              No
# 8     LA             117        408                 No              No
# 9     WV             141        415                Yes             Yes
# 10    IN              65        415                 No              No
# 11    RI              74        415                 No              No
# ...

# %%
dffile[(dffile['International plan'] =='Yes') & (dffile['Churn']==True)]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 41      MD             135        408                Yes             Yes
# 115     ME              36        510                Yes             Yes
# 144     VT             117        408                Yes              No
# 198     ME             131        510                Yes             Yes
# 214     FL              70        510                Yes              No
# ...    ...             ...        ...                ...             ...
# 3246    NC              77        408                Yes             Yes
# 3255    RI             138        510                Yes              No
# 3291    MI             119        510                Yes             Yes
# 3304    IL              71        510                Yes              No
# 3320    GA             122        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# # # check for duplicates

# %%
dffile.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Length: 3333, dtype: bool

# %% [markdown]
# # # Reading in role

# %% [markdown]
# # Removing Duplicate

# %%
dffile.drop_duplicates(inplace=True)

# %%
dffile.iloc[0]
# Out:
# State                        KS
# Account length              128
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        25
# Total day minutes         265.1
# Total day calls           110.0
# Total day charge          45.07
# Total eve minutes         197.4
# Total eve calls            99.0
# Total eve charge          16.78
# Total night minutes       244.7
# Total night calls          91.0
# Total night charge        11.01
# Total intl minutes         10.0
# Total intl calls              3
# Total intl charge           2.7
# Customer service calls      1.0
# Churn                     False
# Ratio                       2.7
# Name: 0, dtype: object

# %%
dffile.iloc[0, 0]
# Out:
# 'KS'

# %%
dffile['Ratio'] = dffile['Total intl charge']/dffile['Customer service calls']

# %%
dffile.dropna(inplace=True)

# %%
dffile.to_csv('output3.csv')
